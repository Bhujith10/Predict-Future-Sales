# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df=pd.read_csv('/kaggle/input/cogo-insurance/FAF5.4_2018-2020.csv')

# %%
commodity_labels_df=pd.read_csv('/kaggle/input/cogo-insurance/comodity-labels.csv')
location_labels_df=pd.read_csv('/kaggle/input/cogo-insurance/location-labels.csv')

# %%
df.head()
# Out:
#    fr_orig  dms_orig  dms_dest  fr_dest  fr_inmode  dms_mode  fr_outmode  \
# 0      NaN        11        11      NaN        NaN         1         NaN
# 1      NaN        11        19      NaN        NaN         1         NaN
# 2      NaN        11       129      NaN        NaN         1         NaN
# 3      NaN        11       131      NaN        NaN         1         NaN
# 4      NaN        11       139      NaN        NaN         1         NaN
#
#    sctg2  trade_type  dist_band  ...   tons_2020  value_2018  value_2019  \
# 0      1           1          1  ...   54.395645   68.594362   71.436584
# 1      1           1          2  ...  411.215079  518.553218  540.039582
# 2      1           1          3  ...    1.450736    1.829418    1.905220
# 3      1           1          2  ...   13.318528   16.795020   17.490925
# 4      1           1          2  ...    5.475181    6.904350    7.190433
#
#    value_2020  current_value_2018  current_value_2019  current_value_2020  \
# 0   71.943453           66.560261           67.993017           62.808675
# 1  543.871367          503.176016          514.007225          474.815125
# 2    1.918738            1.775168            1.813380            1.675113
# 3   17.615030           16.296980           16.647783           15.378421
# 4    7.241452            6.699608            6.843822            6.321993
#
#    tmiles_2018  tmiles_2019  tmiles_2020
# 0     3.218410     3.351765     3.375547
# 1    48.631191    50.646235    51.005589
# 2     0.450066     0.468715     0.472040
# 3     2.177036     2.267241     2.283328
# 4     1.274964     1.327792     1.337213
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2046411 entries, 0 to 2046410
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   fr_orig             float64
#  1   dms_orig            int64
#  2   dms_dest            int64
#  3   fr_dest             float64
#  4   fr_inmode           float64
#  5   dms_mode            int64
#  6   fr_outmode          float64
#  7   sctg2               int64
#  8   trade_type          int64
#  9   dist_band           int64
#  10  tons_2018           float64
#  11  tons_2019           float64
#  12  tons_2020           float64
#  13  value_2018          float64
#  14  value_2019          float64
#  15  value_2020          float64
#  16  current_value_2018  float64
#  17  current_value_2019  float64
#  18  current_value_2020  float64
#  19  tmiles_2018         float64
#  20  tmiles_2019         float64
#  21  tmiles_2020         float64
# dtypes: float64(16), int64(6)
# memory usage: 343.5 MB

# %% [markdown]
# ## Preprocessing

# %%
## Decoding trade type
trade_type_dict={1:'Domestic only',2:'Import',3:'Export'}
df['trade_type'].replace(trade_type_dict,inplace=True)

# %%
## Replacing domestic location id's with their actual location

location_dict={}
for i in range(len(location_labels_df)):
    id=location_labels_df.loc[i]['id']
    region=location_labels_df.loc[i]['region']
    location_dict.update({id:region})
    
df['orig_region']=df['dms_orig'].replace(location_dict)
df['dest_region']=df['dms_dest'].replace(location_dict)

# %%
## Creating state column based on region id's with the help of locations csv file

location_dict={}
for i in range(len(location_labels_df)):
    id=location_labels_df.loc[i]['id']
    state=location_labels_df.loc[i]['state']
    location_dict.update({id:state})
    
df['orig_state']=df['dms_orig'].replace(location_dict)
df['dest_state']=df['dms_dest'].replace(location_dict)

# %%
## Replacing foreign location id's with the country names

country_dict={801:'Canada',802:'Mexico',803:'Rest of America',804:'Europe',
              805:'Africa',806:'SW & Central Asia',807:'Eastern Asia',808:'SE Asia & Oceania'}
    
df['orig_country']=df['fr_orig'].replace(country_dict)
df['dest_country']=df['fr_dest'].replace(country_dict)

# %%
## Replacing trade type id's with their actual trade type names

mode_type_dict={1:'Truck',2:'Rail',3:'Water',4:'Air',
                5:'Multiple Modes and mail',6:'Pipeline',7:'Other and Unknown',8:'No domestic mode'}
df['dms_mode'].replace(mode_type_dict,inplace=True)
df['fr_inmode'].replace(mode_type_dict,inplace=True)
df['fr_outmode'].replace(mode_type_dict,inplace=True)

# %%
## Transforming region column - The first half of region column is stored as region. The second half is stored as state
## Eg : Birmingham-Hoover-Talladega, AL CFS Area ---> Birmingham-Hoover-Talladega -> Region, AL -> State

df['orig_region']=df['orig_region'].apply(lambda x:x.split(',')[0])
df['dest_region']=df['dest_region'].apply(lambda x:x.split(',')[0])

# %%
## Replacing commodity id's with their actual commodity names

commodity_dict={}
for i in range(len(commodity_labels_df)):
    id=commodity_labels_df.loc[i]['id']
    commodity=commodity_labels_df.loc[i]['commodity']
    commodity_dict.update({id:commodity})
    
df['commodity']=df['sctg2'].replace(commodity_dict)

# %%
df.head()
# Out:
#    fr_orig  dms_orig  dms_dest  fr_dest fr_inmode dms_mode fr_outmode  sctg2  \
# 0      NaN        11        11      NaN       NaN    Truck        NaN      1
# 1      NaN        11        19      NaN       NaN    Truck        NaN      1
# 2      NaN        11       129      NaN       NaN    Truck        NaN      1
# 3      NaN        11       131      NaN       NaN    Truck        NaN      1
# 4      NaN        11       139      NaN       NaN    Truck        NaN      1
#
#       trade_type  dist_band  ...  tmiles_2018  tmiles_2019  tmiles_2020  \
# 0  Domestic only          1  ...     3.218410     3.351765     3.375547
# 1  Domestic only          2  ...    48.631191    50.646235    51.005589
# 2  Domestic only          3  ...     0.450066     0.468715     0.472040
# 3  Domestic only          2  ...     2.177036     2.267241     2.283328
# 4  Domestic only          2  ...     1.274964     1.327792     1.337213
#
#                    orig_region                                 dest_region  \
# 0  Birmingham-Hoover-Talladega                 Birmingham-Hoover-Talladega
# 1  Birmingham-Hoover-Talladega                        Remainder of Alabama
# 2  Birmingham-Hoover-Talladega                        Remainder of Florida
# 3  Birmingham-Hoover-Talladega  Atlanta-Athens-Clarke County-Sandy Springs
# 4  Birmingham-Hoover-Talladega                        Remainder of Georgia
#
#    orig_state  dest_state  orig_country  dest_country                commodity
# 0          AL          AL           NaN           NaN  Animals and Fish (live)
# 1          AL          AL           NaN           NaN  Animals and Fish (live)
# 2          AL          FL           NaN           NaN  Animals and Fish (live)
# 3          AL          GA           NaN           NaN  Animals and Fish (live)
# 4          AL          GA           NaN           NaN  Animals and Fish (live)
#
# [5 rows x 29 columns]

# %% [markdown]
# ## EDA

# %%
domestic_df=df[df['trade_type']=='Domestic only']
import_df=df[df['trade_type']=='Import']
export_df=df[df['trade_type']=='Export']

# %% [markdown]
# ## Trade Type Composition

# %%
trade_type_count_df=pd.DataFrame(df['trade_type'].value_counts()).reset_index().rename(columns={'index':'Trade_Type','trade_type':'count'})

fig = go.Figure(data=[go.Pie(labels=trade_type_count_df['Trade_Type'], values=trade_type_count_df['count'], 
                             pull=[0,0.2,0.2],title=dict(text='Trade type composition',font=dict(size=20)))])
fig.update_layout(showlegend=False,margin=dict(l=0,r=0,b=0,t=20))
fig.update_traces(textinfo='percent+label')
fig.add_annotation(x=0.91,y=0.8,xref='paper',yref='paper',text='<b>Imports is slightly higher than exports</b>',showarrow=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="245de7c6-561d-4ea4-ac07-25dae9230f3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("245de7c6-561d-4ea4-ac07-25dae9230f3f")) {                    Plotly.newPlot(                        "245de7c6-561d-4ea4-ac07-25dae9230f3f",                        [{"labels":["Import","Export","Domestic only"],"pull":[0,0.2,0.2],"title":{"font":{"size":20},"text":"Trade type composition"},"values":[777294,746365,522752],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"sca ...
#
# var gd = document.getE

# %%
export_countries_count=export_df.groupby('dest_country',as_index=False).agg({'dms_orig':'count'}).rename(columns={'dest_country':'destination country','dms_orig':'count'})
import_countries_count=import_df.groupby('orig_country',as_index=False).agg({'dms_orig':'count'}).rename(columns={'orig_country':'origin country','dms_orig':'count'})

fig=make_subplots(rows=1, cols=2, specs=[[{"type": "pie"}, {"type": "pie"}]])

fig.add_trace(go.Pie(labels=import_countries_count['origin country'], values=import_countries_count['count'], 
                             pull=[0,0.2,0.2,0.2],title=dict(text='Countries from which USA imports',font=dict(size=20))),row=1,col=1)
fig.add_trace(go.Pie(labels=export_countries_count['destination country'], values=export_countries_count['count'], 
                             pull=[0,0.2,0.2,0.2],title=dict(text='Countries to which USA exports',font=dict(size=20))),row=1,col=2)
fig.update_traces(textinfo='label+percent')
fig.update_layout(margin=dict(l=0,r=0,b=0,t=30),showlegend=False)
fig.show()
# Out:
# <div>                            <div id="207c6144-e77e-4d84-825c-320fb83c9ff8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("207c6144-e77e-4d84-825c-320fb83c9ff8")) {                    Plotly.newPlot(                        "207c6144-e77e-4d84-825c-320fb83c9ff8",                        [{"labels":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"pull":[0,0.2,0.2,0.2],"title":{"font":{"size":20},"text":"Countries from which USA imports"},"values":[40031,101920,146328,173130,56389,75136,92153,92207],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"textinfo":"label+percent"},{"labels":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"pull":[0,0.2,0.2,0.2],"title":{"font":{"size":20},"text":"Countries to which USA exports"},"values":[62949,107268,99256,130752,63158,96892,91107,94983],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"textinfo":"label+percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar": ...

# %% [markdown]
# ## Value of goods traded across years in each trade type

# %%
trade_value_df=df.groupby('trade_type',as_index=False).agg({'current_value_2018':'sum','current_value_2019':'sum','current_value_2020':'sum'})
fig=px.bar(trade_value_df,x='trade_type',y=trade_value_df.columns[1:],barmode='group',title='Total value of goods traded in every trade type')
fig.show()
# Out:
# <div>                            <div id="c5027f6b-41a3-41b4-8179-9b8e6d9b1b7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5027f6b-41a3-41b4-8179-9b8e6d9b1b7a")) {                    Plotly.newPlot(                        "c5027f6b-41a3-41b4-8179-9b8e6d9b1b7a",                        [{"alignmentgroup":"True","hovertemplate":"variable=current_value_2018<br>trade_type=%{x}<br>value=%{y}<extra></extra>","legendgroup":"current_value_2018","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"current_value_2018","offsetgroup":"current_value_2018","orientation":"v","showlegend":true,"textposition":"auto","x":["Domestic only","Export","Import"],"xaxis":"x","y":[16052938.237946,1657732.074465,2436056.556429],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=current_value_2019<br>trade_type=%{x}<br>value=%{y}<extra></extra>","legendgroup":"current_value_2019","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"current_value_2019","offsetgroup":"current_value_2019","orientation":"v","showlegend":true,"textposition":"auto","x":["Domestic only","Export","Import"],"xaxis":"x","y":[15717104.639553,1633359.000862,2384387.474921],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=current_value_2020<br>trade_type=%{x}<br>value=%{y}<extra></extra>","legendgroup":"current_value_2020","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"current_value_2020","offsetgroup":"current_value_2020","orientation":"v","showlegend":true,"textposition":"auto","x":["Domestic only","Export","Import"],"xaxis":"x","y":[14650734.645465,1415444.573087,2225501.353675],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"s ...

# %% [markdown]
# ## Value of goods exported and imported for every country for 2018,2019 and 2020

# %%
import_value_df=import_df.groupby('orig_country',as_index=False).agg({'current_value_2018':'sum','current_value_2019':'sum','current_value_2020':'sum'})
export_value_df=export_df.groupby('dest_country',as_index=False).agg({'current_value_2018':'sum','current_value_2019':'sum','current_value_2020':'sum'})
fig=px.scatter(export_value_df,y='dest_country',x=export_value_df.columns[1:],title='Value of goods exported to all countries for 2018,2019  and 2020')
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')))
fig.update_layout(xaxis=dict(showgrid=False,title='Value (in million dollars)'))
fig.add_annotation(x=0.9,y=0.1,xref='paper',yref='paper',text='<b>For all places there is a decrease in value of exports every year</b>',
                  showarrow=False)
fig.show()
# Out:
# <div>                            <div id="7063ae67-26bb-4b7e-8e08-ceb5e39c8354" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7063ae67-26bb-4b7e-8e08-ceb5e39c8354")) {                    Plotly.newPlot(                        "7063ae67-26bb-4b7e-8e08-ceb5e39c8354",                        [{"hovertemplate":"variable=current_value_2018<br>value=%{x}<br>dest_country=%{y}<extra></extra>","legendgroup":"current_value_2018","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"current_value_2018","orientation":"h","showlegend":true,"x":[23999.268761,344710.183264,306943.183147,325323.375152,264969.239078,174325.343614,111547.022908,105914.458541],"xaxis":"x","y":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=current_value_2019<br>value=%{x}<br>dest_country=%{y}<extra></extra>","legendgroup":"current_value_2019","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"current_value_2019","orientation":"h","showlegend":true,"x":[24534.759891,326746.55776,288157.993305,340350.043543,256011.934983,174556.084506,112593.524572,110408.102302],"xaxis":"x","y":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=current_value_2020<br>value=%{x}<br>dest_country=%{y}<extra></extra>","legendgroup":"current_value_2020","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"current_value_2020","orientation":"h","showlegend":true,"x":[21222.033640999998,273658.581125,285117.840438,297808.964306,210657.554148,138561.429572,100793.211315,87624.958542],"xaxis":"x","y":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks": ...

# %%
fig=px.scatter(import_value_df,y='orig_country',x=import_value_df.columns[1:],title='Value of goods imported from all countries for 2018,2019 and 2020')
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')))
fig.update_layout(xaxis=dict(showgrid=False,title='Value (in million dollars)'))
fig.add_annotation(x=0.6,y=0.9,xref='paper',yref='paper',text='<b>SouthEast Asia & Oceania region is the only place from which<br> value of goods imported increases every year</b>',
                  showarrow=False)
fig.add_annotation(x=0.9,y=0.1,xref='paper',yref='paper',text='<b>For all other places there is a decrease in value of imports every year</b>',
                  showarrow=False)
fig.show()
# Out:
# <div>                            <div id="7a71976e-55c5-4690-bc84-96df89d89a11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a71976e-55c5-4690-bc84-96df89d89a11")) {                    Plotly.newPlot(                        "7a71976e-55c5-4690-bc84-96df89d89a11",                        [{"hovertemplate":"variable=current_value_2018<br>value=%{x}<br>orig_country=%{y}<extra></extra>","legendgroup":"current_value_2018","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"current_value_2018","orientation":"h","showlegend":true,"x":[34942.726365,339631.618046,772920.719164,492778.466228,351799.575997,113685.833976,187430.93638600002,142866.680267],"xaxis":"x","y":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=current_value_2019<br>value=%{x}<br>orig_country=%{y}<extra></extra>","legendgroup":"current_value_2019","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"current_value_2019","orientation":"h","showlegend":true,"x":[29226.300467,337381.37863,700938.895115,515183.258412,360549.562225,101406.775271,210890.538782,128810.766019],"xaxis":"x","y":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=current_value_2020<br>value=%{x}<br>orig_country=%{y}<extra></extra>","legendgroup":"current_value_2020","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"current_value_2020","orientation":"h","showlegend":true,"x":[22905.612416,287302.381843,668362.455781,490055.912156,327040.396065,83730.156615,240004.757615,106099.681184],"xaxis":"x","y":["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# ## Region based analysis

# %%
orig_export_df=export_df.groupby(['dest_country','orig_region'],as_index=False).agg({'current_value_2018':'mean','current_value_2019':'mean','current_value_2020':'mean'}).rename(columns={'current_value_2018':'avg_2018','current_value_2019':'avg_2019','current_value_2020':'avg_2020'})
orig_export_df=orig_export_df.sort_values(['avg_2018'],ascending=[False]).groupby('dest_country').head(1).sort_values(['dest_country','avg_2018'],ascending=[False,False])
fig=px.bar(orig_export_df,x='dest_country',y=orig_export_df.columns[3],barmode='group',text='orig_region',
          title='Top cities from which goods are exported to each country based on the value of goods exported in 2018')
fig.add_annotation(x=0,y=1,xref='paper',yref='paper',text='For example, <b>In the year 2018 on an average 30 million dollars worth of goods have been exported to Mexico from El Paso Las Cruces</b>',
                  showarrow=False)
fig.update_traces(textposition='inside')
fig.update_layout(margin=dict(l=0,r=0,b=0),yaxis=dict(title='Value in Million dollars'))
fig.show()
# Out:
# <div>                            <div id="f1807746-8ff7-408a-8a0a-ada9acd53647" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1807746-8ff7-408a-8a0a-ada9acd53647")) {                    Plotly.newPlot(                        "f1807746-8ff7-408a-8a0a-ada9acd53647",                        [{"alignmentgroup":"True","hovertemplate":"dest_country=%{x}<br>avg_2019=%{y}<br>orig_region=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["Los Angeles-Long Beach","Seattle-Tacoma","Dallas-Fort Worth","El Paso-Las Cruces","Remainder of Texas","Seattle-Tacoma","Detroit-Warren-Ann Arbor","Remainder of Louisiana"],"textposition":"inside","x":["SW & Central Asia","SE Asia & Oceania","Rest of America","Mexico","Europe","Eastern Asia","Canada","Africa"],"xaxis":"x","y":[4.812427477434679,6.261913088642659,10.172711076672105,30.1958287605225,16.630442418401614,15.153280137672091,31.5170465797546,1.7008076023688663],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl": ...

# %%
import_dest_df=import_df.groupby(['orig_country','dest_region'],as_index=False).agg({'current_value_2018':'mean','current_value_2019':'mean','current_value_2020':'mean'}).rename(columns={'current_value_2018':'avg_2018','current_value_2019':'avg_2019','current_value_2020':'avg_2020'})
import_dest_df=import_dest_df.sort_values(['avg_2018'],ascending=[False]).groupby('orig_country').head(1).sort_values(['orig_country','avg_2018'],ascending=[False,False])
fig=px.bar(import_dest_df,x='orig_country',y=import_dest_df.columns[3],barmode='group',text='dest_region',
          title='Top cities to which goods are imported from each country based on the value of goods imported in 2018')
fig.add_annotation(x=0,y=1,xref='paper',yref='paper',text='For example, <b>In the year 2018 on an average 48 million dollars worth of goods have been imported from Mexico to Detroit-Warren-Ann harbour</b>',
                  showarrow=False)
fig.update_traces(textposition='inside')
fig.update_layout(margin=dict(l=0,r=0,b=0),yaxis=dict(title='Value in Million dollars'))
fig.show()
# Out:
# <div>                            <div id="fb1e81b9-433f-4f08-87ee-9ed0dc5af3da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb1e81b9-433f-4f08-87ee-9ed0dc5af3da")) {                    Plotly.newPlot(                        "fb1e81b9-433f-4f08-87ee-9ed0dc5af3da",                        [{"alignmentgroup":"True","hovertemplate":"orig_country=%{x}<br>avg_2019=%{y}<br>dest_region=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["New Orleans-Metairie-Hammond","Los Angeles-Long Beach","New Orleans-Metairie-Hammond","Detroit-Warren-Ann Arbor","New York-Newark","Los Angeles-Long Beach","Detroit-Warren-Ann Arbor","Philadelphia-Reading-Camden"],"textposition":"inside","x":["SW & Central Asia","SE Asia & Oceania","Rest of America","Mexico","Europe","Eastern Asia","Canada","Africa"],"xaxis":"x","y":[3.2973691318897638,16.788310134346503,5.201010394736842,48.69653590866142,10.01822464603349,38.68794288023699,33.51395774409044,3.561997528597786],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outline ...

# %% [markdown]
# ## Top Origin-Destination pairs for domestic trade

# %%
domestic_value_avg_df=domestic_df.groupby(['orig_region','dest_region'],as_index=False).agg({'current_value_2018':'mean','current_value_2019':'mean','current_value_2020':'mean'})
for i in range(len(domestic_value_avg_df)):
    if domestic_value_avg_df['orig_region'][i]==domestic_value_avg_df['dest_region'][i]:
        domestic_value_avg_df.drop(i,axis=0,inplace=True)
domestic_value_avg_df=domestic_value_avg_df.sort_values('current_value_2018',ascending=False)[:20]

domestic_value_sum_df=domestic_df.groupby(['orig_region','dest_region'],as_index=False).agg({'current_value_2018':'sum','current_value_2019':'sum','current_value_2020':'sum'})
for i in range(len(domestic_value_sum_df)):
    if domestic_value_sum_df['orig_region'][i]==domestic_value_sum_df['dest_region'][i]:
        domestic_value_sum_df.drop(i,axis=0,inplace=True)
domestic_value_sum_df=domestic_value_sum_df.sort_values('current_value_2018',ascending=False)[:20]

fig=make_subplots(rows=2,cols=1,specs=[[{'type':'table'}],
                                      [{'type':'table'}]],
                 subplot_titles=['Top Origin-Destination region pairs for domestic trade(Based on average value of goods exported)',
                                'Top Origin-Destination region pairs for domestic trade(Based on total value of goods exported)'])

fig.add_trace(go.Table(header=dict(values=['Origin Region','Destination Region','Value 2018(million $)','Value 2019(million $)','Value 2020(million $)'],font=dict(size=10),align='left'),
                       cells=dict(values=[domestic_value_avg_df[k].tolist() for k in domestic_value_avg_df.columns],align = 'left')),row=1,col=1)
fig.add_trace(go.Table(header=dict(values=['Origin Region','Destination Region','Value 2018(million $)','Value 2019(million $)','Value 2020(million $)'],font=dict(size=10),align='left'),
                       cells=dict(values=[domestic_value_sum_df[k].tolist() for k in domestic_value_sum_df.columns],align = 'left')),row=2,col=1)

fig.update_layout(height=800,width=1000)
fig.add_annotation(x=0,y=0.5,xref='paper',yref='paper'
                   ,text='<b>These tables doesnt take into consideration trades with same origin and destination regions i.e Newyork-Newyork kind of trades</b>',
                  showarrow=False)
fig.show()
# Out:
# <div>                            <div id="cfaf520b-b632-42cf-9a2b-aabb2bfcc410" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfaf520b-b632-42cf-9a2b-aabb2bfcc410")) {                    Plotly.newPlot(                        "cfaf520b-b632-42cf-9a2b-aabb2bfcc410",                        [{"cells":{"align":"left","values":[["Los Angeles-Long Beach","Remainder of Texas","Dallas-Fort Worth","North Dakota","Houston-The Woodlands","Sacramento-Roseville","Remainder of Texas","North Dakota","New Orleans-Metairie-Hammond","Los Angeles-Long Beach","Los Angeles-Long Beach","Remainder of California","Remainder of Michigan","Remainder of Texas","San Jose-San Francisco-Oakland","Dallas-Fort Worth","Los Angeles-Long Beach","North Dakota","Remainder of California","Atlanta-Athens-Clarke County-Sandy Springs"],["San Diego-Carlsbad","Houston-The Woodlands","Remainder of Texas","Lake Charles-Jennings","Remainder of Texas","San Jose-San Francisco-Oakland","New Orleans-Metairie-Hammond","Beaumont-Port Arthur","Baton Rouge","Columbus-Marion-Zanesville","Remainder of California","Los Angeles-Long Beach","Detroit-Warren-Ann Arbor","Dallas-Fort Worth","Remainder of California","Houston-The Woodlands","San Jose-San Francisco-Oakland","New Orleans-Metairie-Hammond","San Jose-San Francisco-Oakland","Remainder of Georgia"],[546.4588355774648,541.0758791445783,537.6835626538461,482.6575755999999,478.4878834868421,476.78288953968257,448.9214439183674,411.040245,356.9818063432836,329.8447255762712,329.17392266666667,322.9145822151899,320.0822968307692,314.0128201265823,309.65507971999995,308.87108793589744,308.1442974257426,289.1166067368421,286.07050005194804,284.61674963513514],[546.146867887324,516.5583218192771,538.1092079871795,472.97595,473.68835392105257,490.4820945238095,438.71786567346936,402.9348827777778,327.54035616417906,343.19481520338985,327.8190831071429,308.92623060759496,318.6169438769231,306.06590029113926,305.50278469333335,310.01327223076925,303.4468372574257,283.324273,274.83133796103897,284.542807],[536.8350880422536,396.249557060241,516.8739024102564,269.80348139999995,445.60312023684213,498.686704968254,279.23617579591837,232.34123566666665,217.6507077761194,349.9645609661017,318.721364202381,287.1938774177215,303.3775672461539,286.2160371139241,301.5112345333333,299.6863049102564,289.4872847128713,161.6607239473684,254.111710987013,277.3973093513514]]},"header":{"align":"left","font":{"size":10},"values":["Origin Region","Destination Region","Value 2018(million $)","Value 2019(million $)","Value 2020(million $)"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.625,1.0]}},{"cells":{"align":"left","values":[["Philadelphia-Reading-Camden","Remainder of Pennsylvania","Remainder of Texas","Dallas-Fort Worth","New York-Newark","Los Angeles-Long Beach","Houston-The Woodlands","Los Angeles-Long Beach","Sacramento-Roseville","Los Angeles-Long Beach","Chicago-Naperville","Los Angeles-Long Beach","New York-Newark","New York-Newark","Hartford-West Hartford-East Hartford","Remainder of California","Chicago-Naperville","Remainder of Texas","San Jose-San Francisco-Oakland","Boston-Worcester-Providence"],["New York-Newark","New York-Newark","Houston-The Woodlands","Remainder of Texas","Philadelphia-Reading-Camden","San Diego-Carlsbad","Remainder of Texas","San Jose-San Francisco-Oakland","San Jose-San Francisco-Oakland","Remainder of California","Remainder of Illinois","New York-Newark","Remainder of Pennsylvania","Boston-Worcester-Providence","New York-Newark","Los Angeles-Long Beach","Remainder of Wisconsin","Dallas-Fort Worth","Los Angeles-Long Beach","New York-Newark"],[48671.756032,47183.333993,44909.297969,41939.317887,39447.002031,38798.577326,36365.079145,31122.57404,30037.322041000003,27650.609504,27 ...

# %% [markdown]
# From the above tables we could find that for all trading routes there is a decrease in average value of goods traded from 2018 to 2020 and the obvious reason is pandemic. But for one particular route <b>Sacramento-Roseville ---> San Jose-San Francisco-Oakland</b> there is an increase in value of goods traded. We can inspect it further

# %% [markdown]
# For this particular trade route the increase in value of goods traded has been predominantly driven by the trading of commodities such as <b>Alcohol & Tobacco, Pharmaceutical Products, Agricultural products</b> etc.
#
# But Alcoholic beverages, Pharmaceutical products have seen increase trading volumes across all routes. One product that has seen increased trading in this particular route is <b>Agricultural products</b>.

# %%
a=domestic_df[(domestic_df['orig_region']=='Sacramento-Roseville')&(domestic_df['dest_region']=='San Jose-San Francisco-Oakland')]
a=a.groupby(['orig_region','dest_region','commodity'],as_index=False).agg({'current_value_2018':'mean','current_value_2019':'mean','current_value_2020':'mean'})
a['pct_2018_2020']=100*(a['current_value_2020']-a['current_value_2018'])/a['current_value_2018']
a.sort_values('pct_2018_2020',ascending=False)[:10].reset_index().drop('index',axis=1)
# Out:
#             orig_region                     dest_region  \
# 0  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 1  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 2  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 3  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 4  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 5  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 6  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 7  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 8  Sacramento-Roseville  San Jose-San Francisco-Oakland
# 9  Sacramento-Roseville  San Jose-San Francisco-Oakland
#
#                                            commodity  current_value_2018  \
# 0          Alcoholic Beverages and Denatured Alcohol           84.104370
# 1                            Pharmaceutical Products         8617.889546
# 2                                   Tobacco Products            0.708874
# 3  Agricultural Products (excludes Animal Feed, C...          224.982184
# 4                                      Natural Sands            2.161713
# 5  Gravel and Crushed Stone (excludes Dolomite an...            0.083120
# 6  Meat, Poultry, Fish, Seafood, and Their Prepar...          318.906611
# 7                                        Fertilizers            6.422140
# 8                                      Wood Products          307.193881
# 9           Other Prepared Foodstuffs, Fats and Oils          452.737667
#
#    current_value_2019  current_value_2020  pct_2018_2020
# 0           85.209193           98.412172      17.011962
# 1         9109.081992         9525.063853      10.526641
# 2            0.723555            0.777412       9.668573
# 3          214.698097          245.816676       9.260508
# 4            2.185548            2.270137       5.015652
# 5            0.083969            0.087157       4.856833
# 6          332.042795          332.426199       4.239356
# 7            7.234081            6.692156       4.204455
# 8          305.191217          319.464124       3.994299
# 9          464.464966          463.641533       2.408429

# %% [markdown]
# ## Highest and Lowest commodities traded based on frequency of trade

# %%
top_commodity=pd.DataFrame(df['commodity'].value_counts()).reset_index().rename(columns={'index':'commodity','commodity':'count'})[:10]
bottom_commodity=pd.DataFrame(df['commodity'].value_counts()).reset_index().rename(columns={'index':'commodity','commodity':'count'})[-10:]
commodity_count_df=pd.concat([top_commodity,bottom_commodity],axis=0).reset_index().drop('index',axis=1)

fig=px.bar(commodity_count_df,y='commodity',x='count',orientation='h',text='commodity')
fig.add_hline(y=9.5, line_width=3, line_dash="dash", line_color="green")
fig.add_annotation(x=1,y=0.7,xref='paper',yref='paper',text='<b>Lowest 10 commodities traded</b>',showarrow=False)
fig.add_annotation(x=1,y=0.3,xref='paper',yref='paper',text='<b>Top 10 commodities traded</b>',showarrow=False)
fig.update_layout(yaxis=dict(showticklabels=False))
# Out:
# <div>                            <div id="ce7c09e9-fb46-491e-8f77-ceb59d7526f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce7c09e9-fb46-491e-8f77-ceb59d7526f9")) {                    Plotly.newPlot(                        "ce7c09e9-fb46-491e-8f77-ceb59d7526f9",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}<br>commodity=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":["Electronic and Other Electrical Equipment and Components, and Office Equipment","Machinery","Plastics and Rubber","Articles of Base Metal","Precision Instruments and Apparatus","Miscellaneous Manufactured Products","Textiles, Leather, and Articles of Textiles or Leather","Motorized and Other Vehicles (includes parts)","Other Chemical Products and Preparations","Transportation Equipment, not elsewhere classified","Animals and Fish (live)","Logs and Other Wood in the Rough","Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Metallic Ores and Concentrates","Tobacco Products","Natural Sands","Gravel and Crushed Stone (excludes Dolomite and Slate)","Monumental or Building Stone","Coal","Crude Petroleum"],"textposition":"auto","x":[128931,121435,101861,100144,98831,95908,93911,92791,82720,82308,12203,11021,9954,8320,8309,7706,6689,5066,3958,2436],"xaxis":"x","y":["Electronic and Other Electrical Equipment and Components, and Office Equipment","Machinery","Plastics and Rubber","Articles of Base Metal","Precision Instruments and Apparatus","Miscellaneous Manufactured Products","Textiles, Leather, and Articles of Textiles or Leather","Motorized and Other Vehicles (includes parts)","Other Chemical Products and Preparations","Transportation Equipment, not elsewhere classified","Animals and Fish (live)","Logs and Other Wood in the Rough","Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Metallic Ores and Concentrates","Tobacco Products","Natural Sands","Gravel and Crushed Stone (excludes Dolomite and Slate)","Monumental or Building Stone","Coal","Crude Petroleum"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %% [markdown]
# ## Highest and Lowest commodities traded based on value of goods(2020)

# %%
top_commodity_value_df=df.groupby('commodity',as_index=False).agg({'current_value_2020':'sum'}).sort_values('current_value_2020',ascending=False)[:10]
bottom_commodity_value_df=df.groupby('commodity',as_index=False).agg({'current_value_2020':'sum'}).sort_values('current_value_2020',ascending=False)[-10:]
commodity_value_df=pd.concat([top_commodity_value_df,bottom_commodity_value_df],axis=0).reset_index().drop('index',axis=1)

fig=px.bar(commodity_value_df,y='commodity',x='current_value_2020',orientation='h',text='commodity')
fig.add_hline(y=9.5, line_width=3, line_dash="dash", line_color="green")
fig.add_annotation(x=1,y=0.7,xref='paper',yref='paper',text='<b>Lowest 10 commodities traded based on value</b>',showarrow=False)
fig.add_annotation(x=1,y=0.3,xref='paper',yref='paper',text='<b>Top 10 commodities traded based on value</b>',showarrow=False)
fig.update_layout(yaxis=dict(showticklabels=False))
# Out:
# <div>                            <div id="60c5c3fa-62cc-483c-abc6-8b3109da8eb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60c5c3fa-62cc-483c-abc6-8b3109da8eb3")) {                    Plotly.newPlot(                        "60c5c3fa-62cc-483c-abc6-8b3109da8eb3",                        [{"alignmentgroup":"True","hovertemplate":"current_value_2020=%{x}<br>commodity=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":["Electronic and Other Electrical Equipment and Components, and Office Equipment","Mixed Freight","Motorized and Other Vehicles (includes parts)","Pharmaceutical Products","Machinery","Miscellaneous Manufactured Products","Plastics and Rubber","Other Prepared Foodstuffs, Fats and Oils","Textiles, Leather, and Articles of Textiles or Leather","Other Coal and Petroleum Products, not elsewhere classified","Tobacco Products","Waste and Scrap (excludes of agriculture or food)","Fertilizers","Metallic Ores and Concentrates","Other Non-Metallic Minerals not elsewhere classified","Coal","Gravel and Crushed Stone (excludes Dolomite and Slate)","Logs and Other Wood in the Rough","Natural Sands","Monumental or Building Stone"],"textposition":"auto","x":[1772448.936971,1583733.457504,1404651.226418,1339369.126743,1176583.63363,915626.593881,824731.657727,744693.213517,624864.007722,584736.033222,90953.022642,82055.985715,71939.624567,29939.566702,27432.835171,22981.544352,22855.487048,15240.250455,13492.898957,6467.405248],"xaxis":"x","y":["Electronic and Other Electrical Equipment and Components, and Office Equipment","Mixed Freight","Motorized and Other Vehicles (includes parts)","Pharmaceutical Products","Machinery","Miscellaneous Manufactured Products","Plastics and Rubber","Other Prepared Foodstuffs, Fats and Oils","Textiles, Leather, and Articles of Textiles or Leather","Other Coal and Petroleum Products, not elsewhere classified","Tobacco Products","Waste and Scrap (excludes of agriculture or food)","Fertilizers","Metallic Ores and Concentrates","Other Non-Metallic Minerals not elsewhere classified","Coal","Gravel and Crushed Stone (excludes Dolomite and Slate)","Logs and Other Wood in the Rough","Natural Sands","Monumental or Building Stone"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %% [markdown]
# ## Top commodities imported and exported for each country based on the count as well as value of goods

# %%
import_commodity_df=import_df.groupby(['orig_country','commodity'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
import_commodity_df=import_commodity_df.sort_values(['orig_country','count'],ascending=[True,False]).groupby('orig_country').head(1)

import_commodity_value_df=import_df.groupby(['orig_country','commodity'],as_index=False).agg({'current_value_2020':'mean'})
import_commodity_value_df=import_commodity_value_df.sort_values(['orig_country','current_value_2020'],ascending=[True,False]).groupby('orig_country').head(3)


fig=make_subplots(rows=2,cols=1,specs=[[{'type':'table'}],
                                      [{'type':'table'}]],
                 subplot_titles=['Top Commodities imported from every country(Based on count)',
                                'Top 3 Commodities imported from every country(Based on value of goods for the year 2020)'])

fig.add_trace(go.Table(header=dict(values=['Origin Country','Destination Region','count'],font=dict(size=10),align='left'),
                       cells=dict(values=[import_commodity_df[k].tolist() for k in import_commodity_df.columns],align = 'left')),row=1,col=1)
fig.add_trace(go.Table(header=dict(values=['Origin Region','Destination Region','Current value 2020 (in million dollars)'],font=dict(size=10),align='left'),
                       cells=dict(values=[import_commodity_value_df[k].tolist() for k in import_commodity_value_df.columns],align = 'left')),row=2,col=1)

fig.update_layout(height=600,width=1000)

fig.show()
# Out:
# <div>                            <div id="198898b0-9747-4b57-a8d9-f14610c4cd0e" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("198898b0-9747-4b57-a8d9-f14610c4cd0e")) {                    Plotly.newPlot(                        "198898b0-9747-4b57-a8d9-f14610c4cd0e",                        [{"cells":{"align":"left","values":[["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],["Textiles, Leather, and Articles of Textiles or Leather","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Machinery","Electronic and Other Electrical Equipment and Components, and Office Equipment","Textiles, Leather, and Articles of Textiles or Leather","Electronic and Other Electrical Equipment and Components, and Office Equipment","Textiles, Leather, and Articles of Textiles or Leather"],[3021,6328,10247,12446,5692,4586,6509,6424]]},"header":{"align":"left","font":{"size":10},"values":["Origin Country","Destination Region","count"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.625,1.0]}},{"cells":{"align":"left","values":[["Africa","Africa","Africa","Canada","Canada","Canada","Eastern Asia","Eastern Asia","Eastern Asia","Europe","Europe","Europe","Mexico","Mexico","Mexico","Rest of America","Rest of America","Rest of America","SE Asia & Oceania","SE Asia & Oceania","SE Asia & Oceania","SW & Central Asia","SW & Central Asia","SW & Central Asia"],["Crude Petroleum","Miscellaneous Manufactured Products","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Crude Petroleum","Motorized and Other Vehicles (includes parts)","Pharmaceutical Products","Electronic and Other Electrical Equipment and Components, and Office Equipment","Motorized and Other Vehicles (includes parts)","Machinery","Crude Petroleum","Pharmaceutical Products","Miscellaneous Manufactured Products","Crude Petroleum","Motorized and Other Vehicles (includes parts)","Electronic and Other Electrical Equipment and Components, and Office Equipment","Crude Petroleum","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Electronic and Other Electrical Equipment and Components, and Office Equipment","Textiles, Leather, and Articles of Textiles or Leather","Miscellaneous Manufactured Products","Crude Petroleum","Other Coal and Petroleum Products, not elsewhere classified","Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)"],[59.88781528571429,4.435798473544974,2.2167546572769954,225.13769447089945,11.232605672666494,8.425664526258798,23.19807108646433,10.917612414937132,7.468664157801047,32.44757382666667,19.406742517082375,7.382046382866648,240.1953325277778,24.551863074417213,16.19129241373858,155.83803323636366,4.305172838164252,3.699362698934551,13.49393495974804,6.05245742062654,4.537717468074534,209.45700016000004,5.77993339057239,3.8516304934640524]]},"header":{"align":"left","font":{"size":10},"values":["Origin Region","Destination Region","Current value 2020 (in million dollars)"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.0,0.375]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type" ...

# %%
export_commodity_df=export_df.groupby(['dest_country','commodity'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
export_commodity_df=export_commodity_df.sort_values(['dest_country','count'],ascending=[True,False]).groupby('dest_country').head(1)

export_commodity_value_df=export_df.groupby(['dest_country','commodity'],as_index=False).agg({'current_value_2020':'mean'})
export_commodity_value_df=export_commodity_value_df.sort_values(['dest_country','current_value_2020'],ascending=[True,False]).groupby('dest_country').head(3)

fig=make_subplots(rows=2,cols=1,specs=[[{'type':'table'}],
                                      [{'type':'table'}]],
                 subplot_titles=['Top Commodities exported to every country(Based on count)',
                                'Top 3 Commodities exported to every country(Based on value of goods for the year 2020)'])

fig.add_trace(go.Table(header=dict(values=['Origin Country','Destination Region','count'],font=dict(size=10),align='left'),
                       cells=dict(values=[export_commodity_df[k].tolist() for k in export_commodity_df.columns],align = 'left')),row=1,col=1)
fig.add_trace(go.Table(header=dict(values=['Origin Region','Destination Region','Current value 2020 (in million dollars)'],font=dict(size=10),align='left'),
                       cells=dict(values=[export_commodity_value_df[k].tolist() for k in export_commodity_value_df.columns],align = 'left')),row=2,col=1)

fig.update_layout(height=600,width=1000)

fig.show()
# Out:
# <div>                            <div id="4f0f47d3-3118-4461-8ca1-0171076bfd67" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f0f47d3-3118-4461-8ca1-0171076bfd67")) {                    Plotly.newPlot(                        "4f0f47d3-3118-4461-8ca1-0171076bfd67",                        [{"cells":{"align":"left","values":[["Africa","Canada","Eastern Asia","Europe","Mexico","Rest of America","SE Asia & Oceania","SW & Central Asia"],["Machinery","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Machinery","Electronic and Other Electrical Equipment and Components, and Office Equipment"],[4200,6813,5436,7347,4283,5278,4970,5588]]},"header":{"align":"left","font":{"size":10},"values":["Origin Country","Destination Region","count"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.625,1.0]}},{"cells":{"align":"left","values":[["Africa","Africa","Africa","Canada","Canada","Canada","Eastern Asia","Eastern Asia","Eastern Asia","Europe","Europe","Europe","Mexico","Mexico","Mexico","Rest of America","Rest of America","Rest of America","SE Asia & Oceania","SE Asia & Oceania","SE Asia & Oceania","SW & Central Asia","SW & Central Asia","SW & Central Asia"],["Crude Petroleum","Other Coal and Petroleum Products, not elsewhere classified","Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Crude Petroleum","Mixed Freight","Motorized and Other Vehicles (includes parts)","Crude Petroleum","Other Coal and Petroleum Products, not elsewhere classified","Electronic and Other Electrical Equipment and Components, and Office Equipment","Crude Petroleum","Miscellaneous Manufactured Products","Pharmaceutical Products","Mixed Freight","Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Electronic and Other Electrical Equipment and Components, and Office Equipment","Crude Petroleum","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Crude Petroleum","Electronic and Other Electrical Equipment and Components, and Office Equipment","Machinery","Crude Petroleum","Coal","Other Coal and Petroleum Products, not elsewhere classified"],[9.758391526315789,1.9264220034188033,1.5512840443661973,60.4375081588785,39.26438046470588,11.134119569171057,347.79039752631576,10.805548519961052,8.514322817328917,437.85794116216215,6.386501472589459,5.870608010251153,13.635843742937853,13.268613878223494,11.453071961709083,141.0148052352941,10.5799629,6.847807119914347,138.594496375,3.9672436522442376,2.809273924144869,176.04262373076924,3.5450411111111113,3.0818569882854097]]},"header":{"align":"left","font":{"size":10},"values":["Origin Region","Destination Region","Current value 2020 (in million dollars)"]},"type":"table","domain":{"x":[0.0,1.0],"y":[0.0,0.375]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# ## Top commodities traded domestically based on value of goods

# %% [markdown]
# If we consider top commodites for import and export based on value of goods, <b>crude petroleum</b> occupies the top most position

# %%
commodity_value_domestic_df=domestic_df.groupby(['commodity'],as_index=False).agg({'current_value_2018':'mean','current_value_2019':'mean','current_value_2020':'mean'}).sort_values('current_value_2018',ascending=False)[:15]
fig=px.bar(commodity_value_domestic_df,x='commodity',y=commodity_value_domestic_df.columns[1:],barmode='group')
fig.add_annotation(x=0.1,y=0.8,xref='paper',yref='paper',text='<b>Pharmaceuticals, Tobacco, Alcohol and Meat products</b> are the categories <br>where there is a slight increase in value of goods over years',
                  showarrow=False)
fig.update_layout(margin=dict(l=0,r=0),yaxis=dict(title='Value in million dollars'))
fig.show()
# Out:
# <div>                            <div id="c823c3ff-0fa7-4429-8352-dd332b1c2e12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c823c3ff-0fa7-4429-8352-dd332b1c2e12")) {                    Plotly.newPlot(                        "c823c3ff-0fa7-4429-8352-dd332b1c2e12",                        [{"alignmentgroup":"True","hovertemplate":"variable=current_value_2018<br>commodity=%{x}<br>value=%{y}<extra></extra>","legendgroup":"current_value_2018","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"current_value_2018","offsetgroup":"current_value_2018","orientation":"v","showlegend":true,"textposition":"auto","x":["Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Crude Petroleum","Animals and Fish (live)","Other Coal and Petroleum Products, not elsewhere classified","Cereal Grains (includes seed)","Pharmaceutical Products","Mixed Freight","Coal","Meat, Poultry, Fish, Seafood, and Their Preparations","Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Alcoholic Beverages and Denatured Alcohol","Motorized and Other Vehicles (includes parts)","Other Prepared Foodstuffs, Fats and Oils","Electronic and Other Electrical Equipment and Components, and Office Equipment"],"xaxis":"x","y":[588.3272591443779,450.6299757516581,148.60605001749096,113.03356404554327,93.11524764750803,83.14721422050772,66.56554442535067,57.79664012642244,48.09604346374046,45.15811808125325,44.42014486684385,43.39150813600729,41.82108387466927,39.383970300927075,32.74147785322425],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=current_value_2019<br>commodity=%{x}<br>value=%{y}<extra></extra>","legendgroup":"current_value_2019","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"current_value_2019","offsetgroup":"current_value_2019","orientation":"v","showlegend":true,"textposition":"auto","x":["Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Crude Petroleum","Animals and Fish (live)","Other Coal and Petroleum Products, not elsewhere classified","Cereal Grains (includes seed)","Pharmaceutical Products","Mixed Freight","Coal","Meat, Poultry, Fish, Seafood, and Their Preparations","Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Alcoholic Beverages and Denatured Alcohol","Motorized and Other Vehicles (includes parts)","Other Prepared Foodstuffs, Fats and Oils","Electronic and Other Electrical Equipment and Components, and Office Equipment"],"xaxis":"x","y":[539.464930934797,394.64790728887255,143.24808027864898,114.01809570071568,79.38829243368167,83.0597653066202,70.35956993262025,57.695098866507884,45.555499026717555,47.30242763871555,39.99811328943522,43.96151385633546,41.40113190610639,40.66078662224969,32.82149862601171],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=current_value_2020<br>commodity=%{x}<br>value=%{y}<extra></extra>","legendgroup":"current_value_2020","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"current_value_2020","offsetgroup":"current_value_2020","orientation":"v","showlegend":true,"textposition":"auto","x":["Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Crude Petroleum","Animals and Fish (live)","Other Coal and Petroleum Products, not elsewhere classified","Cereal Grains (includes seed)","Pharmaceutical Products","Mixed Freight","Coal","Meat, Poultry, Fish, Seafood, and Their Preparations","Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Alcoholic ...

# %% [markdown]
# ## Top 5 commodites traded in every trade type

# %%
trade_commodity_groupby=df.groupby(['trade_type','commodity'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
trade_commodity_groupby=trade_commodity_groupby.sort_values(['trade_type','count'],ascending=[True,False]).groupby('trade_type').head(5)
fig=px.treemap(trade_commodity_groupby,path=['trade_type','commodity'],values='count',title='Top commodities traded in every trade type')
fig.update_layout(margin=dict(l=0,b=0,r=0,t=40))
fig.add_annotation(x=0.1,y=1,xref='paper',yref='paper',text='<b>Machinery, Electronic items, precision instruments are the most traded in every category</b>',showarrow=False)
fig.show()
# Out:
# <div>                            <div id="8921ae90-b217-4942-965e-6e212cbdf691" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8921ae90-b217-4942-965e-6e212cbdf691")) {                    Plotly.newPlot(                        "8921ae90-b217-4942-965e-6e212cbdf691",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Export/Articles of Base Metal","Import/Articles of Base Metal","Domestic only/Electronic and Other Electrical Equipment and Components, and Office Equipment","Export/Electronic and Other Electrical Equipment and Components, and Office Equipment","Import/Electronic and Other Electrical Equipment and Components, and Office Equipment","Domestic only/Machinery","Export/Machinery","Import/Machinery","Domestic only/Miscellaneous Manufactured Products","Domestic only/Mixed Freight","Domestic only/Motorized and Other Vehicles (includes parts)","Export/Plastics and Rubber","Export/Precision Instruments and Apparatus","Import/Precision Instruments and Apparatus","Import/Textiles, Leather, and Articles of Textiles or Leather","Domestic only","Export","Import"],"labels":["Articles of Base Metal","Articles of Base Metal","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Electronic and Other Electrical Equipment and Components, and Office Equipment","Machinery","Machinery","Machinery","Miscellaneous Manufactured Products","Mixed Freight","Motorized and Other Vehicles (includes parts)","Plastics and Rubber","Precision Instruments and Apparatus","Precision Instruments and Apparatus","Textiles, Leather, and Articles of Textiles or Leather","Domestic only","Export","Import"],"name":"","parents":["Export","Import","Domestic only","Export","Import","Domestic only","Export","Import","Domestic only","Domestic only","Domestic only","Export","Export","Import","Import","","",""],"values":[36003,39718,33977,43848,51106,27580,42352,51503,33425,26451,28724,36607,37393,39331,40690,150157,196203,222348],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %% [markdown]
# ## Commodities and trade type

# %%
commodity_trade_groupby=df.groupby(['commodity','trade_type'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
commodity_trade_groupby=commodity_trade_groupby.sort_values(['commodity','count'],ascending=[True,False]).groupby('commodity').head()
commodity_trade_groupby['pct']=commodity_trade_groupby.groupby('commodity')['count'].apply(lambda x:round(x*100/x.sum(),2))

fig=px.bar(commodity_trade_groupby,y='commodity',color='trade_type',x='pct',orientation='h',
           width=1000,height=1000,text='pct',title='Commodities categorized by trade type')
fig.update_layout(margin=dict(l=0,r=0,b=0))
fig.add_annotation(x=-2.1,y=0.82,xref='paper',yref='paper',
                   text='<b>Crude Petroleum is majorly imported while <br>coal is majorly exported<br><br>Cereal grains, fuel oils, wooden logs <br>and waste scrap are predominantly exported</b>',
                  showarrow=False)
fig.show()
# Out:
# <div>                            <div id="0cab5157-242e-4d69-8145-624d4eca19e6" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cab5157-242e-4d69-8145-624d4eca19e6")) {                    Plotly.newPlot(                        "0cab5157-242e-4d69-8145-624d4eca19e6",                        [{"alignmentgroup":"True","hovertemplate":"trade_type=Import<br>pct=%{text}<br>commodity=%{y}<extra></extra>","legendgroup":"Import","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Import","offsetgroup":"Import","orientation":"h","showlegend":true,"text":[44.64,43.65,38.18,40.85,39.66,38.2,39.37,36.96,21.83,20.03,39.64,41.52,31.39,40.89,28.65,45.01,23.19,42.41,39.69,37.96,37.04,33.75,32.6,47.49,34.43,25.4,43.84,33.48,24.59,40.83,36.53,39.05,32.94,38.49,39.8,31.7,36.37,43.33,32.19,32.44,37.83,44.53],"textposition":"auto","x":[44.64,43.65,38.18,40.85,39.66,38.2,39.37,36.96,21.83,20.03,39.64,41.52,31.39,40.89,28.65,45.01,23.19,42.41,39.69,37.96,37.04,33.75,32.6,47.49,34.43,25.4,43.84,33.48,24.59,40.83,36.53,39.05,32.94,38.49,39.8,31.7,36.37,43.33,32.19,32.44,37.83,44.53],"xaxis":"x","y":["Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Alcoholic Beverages and Denatured Alcohol","Animal Feed, Eggs, Honey, and Other Products of Animal Origin","Animals and Fish (live)","Articles of Base Metal","Base Metal in Primary or Semi-Finished Forms and in Finished Basic Shapes","Basic Chemicals","Cereal Grains (includes seed)","Coal","Crude Petroleum","Electronic and Other Electrical Equipment and Components, and Office Equipment","Fertilizers","Fuel Oils (includes Diesel, Bunker C, and Biodiesel)","Furniture, Mattresses and Mattress Supports, Lamps, Lighting Fittings, and Illuminated Signs","Gasoline, Aviation Turbine Fuel, and Ethanol (includes Kerosene, and Fuel Alcohols)","Gravel and Crushed Stone (excludes Dolomite and Slate)","Logs and Other Wood in the Rough","Machinery","Meat, Poultry, Fish, Seafood, and Their Preparations","Metallic Ores and Concentrates","Milled Grain Products and Preparations, and Bakery Products","Miscellaneous Manufactured Products","Mixed Freight","Monumental or Building Stone","Motorized and Other Vehicles (includes parts)","Natural Sands","Non-Metallic Mineral Products","Other Chemical Products and Preparations","Other Coal and Petroleum Products, not elsewhere classified","Other Non-Metallic Minerals not elsewhere classified","Other Prepared Foodstuffs, Fats and Oils","Paper or Paperboard Articles","Pharmaceutical Products","Plastics and Rubber","Precision Instruments and Apparatus","Printed Products","Pulp, Newsprint, Paper, and Paperboard","Textiles, Leather, and Articles of Textiles or Leather","Tobacco Products","Transportation Equipment, not elsewhere classified","Waste and Scrap (excludes of agriculture or food)","Wood Products"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"trade_type=Export<br>pct=%{text}<br>commodity=%{y}<extra></extra>","legendgroup":"Export","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Export","offsetgroup":"Export","orientation":"h","showlegend":true,"text":[39.29,34.91,44.76,46.55,35.95,36.46,39.2,50.64,64.93,11.9,34.01,43.74,59.37,28.79,56.25,29.53,69.69,34.88,38.55,46.88,37.07,31.4,16.48,29.57,34.62,49.39,35.94,41.05,42.45,40.92,37.38,33.7,38.59,35.94,37.84,33.02,38.84,29.13,32.36,41.83,52.67,30.76],"textposition":"auto","x":[39.29,34.91,44.76,46.55,35.95,36.46,39.2,50.64,64.93,11.9,34.01,43.74,59.37,28.79,56.25,29.53,69.69,34.88,38.55,46.88,37.07,31.4,16.48,29.57,34.62,49.39,35.94,41.05,42.45,40.92,37.38,33.7,38.59,35.94,37.84,33.02,38.84,29.13,32.36,41.83,52.67,30.76],"xaxis":"x","y":["Agricultural Products (excludes Animal Feed, Cereal Grains, and Forage Products)","Alc ...

# %% [markdown]
# ## Preferred Transportation mode in every trade type

# %%
dms_mode_groupby=df.groupby('dms_mode',as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
fr_inmode_groupby=df.groupby('fr_inmode',as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
fr_outmode_groupby=df.groupby('fr_outmode',as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})

fig=make_subplots(rows=3,cols=1,subplot_titles=['Transportation modes used during domestic trade movement',
                                               'Transportation modes used during import',
                                               'Transportation modes used during export'])
fig.add_trace(go.Bar(x=dms_mode_groupby['dms_mode'],y=dms_mode_groupby['count'],name='Domestic'),row=1,col=1)
fig.add_trace(go.Bar(x=fr_inmode_groupby['fr_inmode'],y=fr_inmode_groupby['count'],name='Import'),row=2,col=1)
fig.add_trace(go.Bar(x=fr_outmode_groupby['fr_outmode'],y=fr_outmode_groupby['count'],name='Export'),row=3,col=1)
fig.add_annotation(x=0.3,y=0.95,xref='paper',yref='paper',
                   text='<b>Truck is the most used transportation method in domestic travel.</b>',
                  showarrow=False)
fig.add_annotation(x=0.25,y=0.5,xref='paper',yref='paper',
                   text='<b>Air and water is the most used transportation method in export and import.</b>',
                  showarrow=False)
fig.update_layout(height=1000,width=1000,margin=dict(l=0,r=0,b=0,t=30))
# Out:
# <div>                            <div id="54bde67a-ff60-4fd6-888a-a3fdf2f92b75" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54bde67a-ff60-4fd6-888a-a3fdf2f92b75")) {                    Plotly.newPlot(                        "54bde67a-ff60-4fd6-888a-a3fdf2f92b75",                        [{"name":"Domestic","x":["Air","Multiple Modes and mail","No domestic mode","Other and Unknown","Pipeline","Rail","Truck","Water"],"y":[545731,429697,105,4643,3746,271195,752055,39239],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Import","x":["Air","Multiple Modes and mail","Other and Unknown","Pipeline","Rail","Truck","Water"],"y":[328639,30135,2957,268,16565,47636,351094],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Export","x":["Air","Multiple Modes and mail","Other and Unknown","Pipeline","Rail","Truck","Water"],"y":[332135,14771,1672,405,21144,52634,323604],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f ...

# %% [markdown]
# ## Top commodities traded via different transportation modes in different trades

# %% [markdown]
# <b>Truck</b> is a major transportation mode in domestic trade movement.
#
# Irrespective of trade type, <b>electical and electornic equipments</b> cover a major portion in air, water and truck transportation modes.
#
# <b>Machinery</b> is majorly imported or exported via water ways compared with airways.

# %%
a=df.groupby(['dms_mode','commodity'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
a=a.sort_values(['dms_mode','count'],ascending=[True,False]).groupby('dms_mode').head(5)
fig=px.bar(a,x='dms_mode',y='count',color='commodity',title='Top commodities traded via transportation modes in all doemstic trade')
fig.show()
# Out:
# <div>                            <div id="838ce579-6a5a-4e40-be0f-65dcf2657eac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("838ce579-6a5a-4e40-be0f-65dcf2657eac")) {                    Plotly.newPlot(                        "838ce579-6a5a-4e40-be0f-65dcf2657eac",                        [{"alignmentgroup":"True","hovertemplate":"commodity=Electronic and Other Electrical Equipment and Components, and Office Equipment<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Electronic and Other Electrical Equipment and Components, and Office Equipment","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Electronic and Other Electrical Equipment and Components, and Office Equipment","offsetgroup":"Electronic and Other Electrical Equipment and Components, and Office Equipment","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Other and Unknown","Truck","Water"],"xaxis":"x","y":[51289,26737,337,38383,1780],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Machinery<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Machinery","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machinery","offsetgroup":"Machinery","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Rail","Truck","Water"],"xaxis":"x","y":[43720,26477,12629,36312,2186],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Precision Instruments and Apparatus<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Precision Instruments and Apparatus","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Precision Instruments and Apparatus","offsetgroup":"Precision Instruments and Apparatus","orientation":"v","showlegend":true,"textposition":"auto","x":["Air"],"xaxis":"x","y":[42436],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Articles of Base Metal<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Articles of Base Metal","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Articles of Base Metal","offsetgroup":"Articles of Base Metal","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Rail","Water"],"xaxis":"x","y":[31598,13349,1997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Plastics and Rubber<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Plastics and Rubber","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Plastics and Rubber","offsetgroup":"Plastics and Rubber","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Rail","Truck","Water"],"xaxis":"x","y":[30205,22748,12832,33909,1998],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Textiles, Leather, and Articles of Textiles or Leather<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Textiles, Leather, and Articles of Textiles or Leather","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Textiles, Leather, and Articles of Textiles or Leather","offsetgroup":"Textiles, Leather, and Articles of Textiles or Leather","orientation":"v","showlegend":true,"textposition":"auto","x":["Multiple Modes and mail"],"xaxis":"x","y":[24973],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Miscellaneous Manufactured Products<br>dms_mode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Miscellaneous Manufactured Products","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Miscellaneous Manufactured Products","offsetgroup":"Miscellaneous Manufactured Products","orientation":"v","showlegend":true,"textposition":"auto","x":["Multiple Modes and mail","Truck" ...

# %%
a=df.groupby(['fr_inmode','commodity'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
a=a.sort_values(['fr_inmode','count'],ascending=[True,False]).groupby('fr_inmode').head(5)
fig=px.bar(a,x='fr_inmode',y='count',color='commodity',title='Top commodities traded via transportation modes in imports')
fig.show()
# Out:
# <div>                            <div id="e4c11c39-45a9-4559-b4e2-3768a26873e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4c11c39-45a9-4559-b4e2-3768a26873e7")) {                    Plotly.newPlot(                        "e4c11c39-45a9-4559-b4e2-3768a26873e7",                        [{"alignmentgroup":"True","hovertemplate":"commodity=Electronic and Other Electrical Equipment and Components, and Office Equipment<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Electronic and Other Electrical Equipment and Components, and Office Equipment","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Electronic and Other Electrical Equipment and Components, and Office Equipment","offsetgroup":"Electronic and Other Electrical Equipment and Components, and Office Equipment","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Truck"],"xaxis":"x","y":[30712,1764,1821],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Machinery<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Machinery","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machinery","offsetgroup":"Machinery","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Truck","Water"],"xaxis":"x","y":[27611,1871,1937,19529],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Precision Instruments and Apparatus<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Precision Instruments and Apparatus","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Precision Instruments and Apparatus","offsetgroup":"Precision Instruments and Apparatus","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail"],"xaxis":"x","y":[24410,1610],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Textiles, Leather, and Articles of Textiles or Leather<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Textiles, Leather, and Articles of Textiles or Leather","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Textiles, Leather, and Articles of Textiles or Leather","offsetgroup":"Textiles, Leather, and Articles of Textiles or Leather","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Water"],"xaxis":"x","y":[20764,16451],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Articles of Base Metal<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Articles of Base Metal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Articles of Base Metal","offsetgroup":"Articles of Base Metal","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Truck","Water"],"xaxis":"x","y":[18570,1619,1850,17020],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Plastics and Rubber<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Plastics and Rubber","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Plastics and Rubber","offsetgroup":"Plastics and Rubber","orientation":"v","showlegend":true,"textposition":"auto","x":["Multiple Modes and mail","Rail","Truck","Water"],"xaxis":"x","y":[1627,943,1852,16983],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Pharmaceutical Products<br>fr_inmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Pharmaceutical Products","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Pharmaceutical Products","offsetgroup":"Pharmaceutical Products","orientation":"v","showlegend":true,"textposition":"auto","x":["Other and Unknown"],"xaxis":"x","y":[759],"yaxis":"y","type":"bar"},{"alignmentgroup ...

# %%
a=df.groupby(['fr_outmode','commodity'],as_index=False).agg({'dms_orig':'count'}).rename(columns={'dms_orig':'count'})
a=a.sort_values(['fr_outmode','count'],ascending=[True,False]).groupby('fr_outmode').head(5)
fig=px.bar(a,x='fr_outmode',y='count',color='commodity',title='Top commodities traded via transportation modes in exports')
fig.show()
# Out:
# <div>                            <div id="798c260d-0339-4b37-874a-2d621a846e34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("798c260d-0339-4b37-874a-2d621a846e34")) {                    Plotly.newPlot(                        "798c260d-0339-4b37-874a-2d621a846e34",                        [{"alignmentgroup":"True","hovertemplate":"commodity=Electronic and Other Electrical Equipment and Components, and Office Equipment<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Electronic and Other Electrical Equipment and Components, and Office Equipment","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Electronic and Other Electrical Equipment and Components, and Office Equipment","offsetgroup":"Electronic and Other Electrical Equipment and Components, and Office Equipment","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Other and Unknown","Truck","Water"],"xaxis":"x","y":[26421,1075,165,1824,13679],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Precision Instruments and Apparatus<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Precision Instruments and Apparatus","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Precision Instruments and Apparatus","offsetgroup":"Precision Instruments and Apparatus","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Other and Unknown"],"xaxis":"x","y":[23404,858,140],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Machinery<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Machinery","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Machinery","offsetgroup":"Machinery","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Truck","Water"],"xaxis":"x","y":[22515,1159,1893,15871],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Transportation Equipment, not elsewhere classified<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Transportation Equipment, not elsewhere classified","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Transportation Equipment, not elsewhere classified","offsetgroup":"Transportation Equipment, not elsewhere classified","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Other and Unknown"],"xaxis":"x","y":[20457,216],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Articles of Base Metal<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Articles of Base Metal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Articles of Base Metal","offsetgroup":"Articles of Base Metal","orientation":"v","showlegend":true,"textposition":"auto","x":["Air","Multiple Modes and mail","Truck"],"xaxis":"x","y":[19269,794,1759],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Plastics and Rubber<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Plastics and Rubber","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Plastics and Rubber","offsetgroup":"Plastics and Rubber","orientation":"v","showlegend":true,"textposition":"auto","x":["Multiple Modes and mail","Rail","Truck","Water"],"xaxis":"x","y":[805,1054,1799,14545],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"commodity=Motorized and Other Vehicles (includes parts)<br>fr_outmode=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Motorized and Other Vehicles (includes parts)","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Motorized and Other Vehicles (includes parts)","offsetgroup":"Motorized and Other Vehicles (includes parts)","orientation" ...

# %% [markdown]
# ## Value of goods transported via multiple modes across every trade type

# %% [markdown]
# <b>Trucks</b> are predominantly used in <b>domestic trade</b> and obviously the value of goods they ship is also higher.
#
# Goods transported via <b>waterways possess more value in import based trade and export based trade</b> while airways closely follows waterways in exports. The below plot takes into account value of goods in 2020.

# %%
dms_mode_value=df.groupby('dms_mode',as_index=False).agg({'current_value_2020':'sum'})
fr_inmode_value=df.groupby('fr_inmode',as_index=False).agg({'current_value_2020':'sum'})
fr_outmode_value=df.groupby('fr_outmode',as_index=False).agg({'current_value_2020':'sum'})

fig=make_subplots(rows=3,cols=1,subplot_titles=['Value of goods transported via different modes in domestic trade',
                                               'Value of goods transported via different modes in imports',
                                               'Value of goods transported via different modes in exports'])
fig.add_trace(go.Bar(x=dms_mode_value['dms_mode'],y=dms_mode_value['current_value_2020'],name='Domestic'),row=1,col=1)
fig.add_trace(go.Bar(x=fr_inmode_value['fr_inmode'],y=fr_inmode_value['current_value_2020'],name='Import'),row=2,col=1)
fig.add_trace(go.Bar(x=fr_outmode_value['fr_outmode'],y=fr_outmode_value['current_value_2020'],name='Export'),row=3,col=1)

fig.update_layout(height=1000,width=1000,margin=dict(l=0,r=0,b=0,t=30))
# Out:
# <div>                            <div id="44b10ce0-4dae-4623-89b2-b7067480bb2a" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44b10ce0-4dae-4623-89b2-b7067480bb2a")) {                    Plotly.newPlot(                        "44b10ce0-4dae-4623-89b2-b7067480bb2a",                        [{"name":"Domestic","x":["Air","Multiple Modes and mail","No domestic mode","Other and Unknown","Pipeline","Rail","Truck","Water"],"y":[624595.201517,2603186.44168,28299.754378,11023.236929,804672.25554,536369.690154,13461482.878017,222051.114012],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Import","x":["Air","Multiple Modes and mail","Other and Unknown","Pipeline","Rail","Truck","Water"],"y":[649423.238271,47355.570487,2613.693922,42408.246671999994,99208.483164,366615.40013,1017876.721029],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Export","x":["Air","Multiple Modes and mail","Other and Unknown","Pipeline","Rail","Truck","Water"],"y":[473932.739849,21299.045089,6883.8987910000005,11680.521055,56170.238976,325894.843618,519583.285709],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidt ...

# %% [markdown]
# ## SUMMARY
#
# <b>New York</b> acts as an important region via which goods are traded.
#
# <b>New York-Newark to  Philadelphia-Reading-Camden</b> is an important route via which a lot of trade movement occurs.
#
# <b>Los Angeles-San Deigo</b> trade route is the top domestic trade route based on the average value of goods shipped between them while Newyork-Philadelphia is the top domestic trade route based on total value of goods shipped.
#
# In this given dataset, <b>38% accounts for imports while 36% accounts for exports and 25% covers domestic trade.</b>
#
# <b>Europe, Eastern Asia and Canada</b> are top regions from which USA exports and imports.
#
# In the given dataset <b>based on the value of goods traded, domestic trade occupies the first spot</b> while imports and exports lags behind.
#
# For all years, for all regions there is a decrease in value of goods exported and imported while <b>SouthEast Asia and Oceania is the only region where there is a increase in value of goods imported from 2018 to 2020.</b>
#
# <b>Based on value of goods, Electrical and electronic equipments is the top commodity to be traded while Monumental or Building stones is the lowest commodity traded</b>.
#
# <b>Based on weight of goods shipped, Coal and Petroleum products is the top commodity while tobacco products is the lowest commodity</b>.
#
# <b>Textiles or Electrical equipments is the most imported commodity across all regions</b> while <b>Machinery</b> is the most imported commodity from <b>Europe</b>.
#
# <b>Crude Petroleum is the costliest commodity</b> either imported or exported from/to almost all regions.
#
# <b>Crude Petroleum is majorly imported<b> while <b>coal is majorly exported</b>.
#
# <b>Cereal grains, fuel oils, wooden logs and waste scrap are predominantly exported</b>.
#
# <b>Trucks are the preferred mode of transportation in domestic trade while Airways and Waterways are the preferred mode in import and exports</b>.
#
# During <b>imports and exports waterways carries the heaviest goods</b>.
